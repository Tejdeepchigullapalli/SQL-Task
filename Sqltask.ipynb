# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejdeepchigullapalli/SQL-Task/blob/main/Sqltask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Create an SQLite database
#
# SQLite is a C-language library that implements a small, fast, self-contained, high-reliability, full-featured, SQL database engine. It's often used for embedded databases and is ideal for local development and testing within Colab because it doesn't require a separate server process.

# %%
#create data base in colab
import sqlite3
import pandas as pd

# Define the database file name
db_name = 'my_database.db'

# Connect to SQLite database (this will create the file if it doesn't exist)
conn = sqlite3.connect(db_name)
cursor = conn.cursor()

print(f"Database '{db_name}' created and connected successfully.")
# Out:
# Database 'my_database.db' created and connected successfully.

# %% [markdown]
# ### Create a table
#
# Now, let's create a simple table named `users` with columns for `id`, `name`, and `email`.

# %%
# Create a table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS users (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        name TEXT NOT NULL,
        email TEXT UNIQUE NOT NULL
    )
''')
conn.commit()

print("Table 'users' created successfully.")
# Out:
# Table 'users' created successfully.

# %% [markdown]
# ### Insert data into the table
#
# Let's add a few rows of data to our `users` table.

# %%
# Insert data
users_data = [
    ('Alice', 'alice@example.com'),
    ('Bob', 'bob@example.com'),
    ('Charlie', 'charlie@example.com')
]

cursor.executemany("INSERT INTO users (name, email) VALUES (?, ?)", users_data)
conn.commit()

print("Data inserted successfully.")
# Out:
# Data inserted successfully.

# %% [markdown]
# ### Query data from the table
#
# Finally, let's retrieve and display the data we just inserted.

# %%
# Query data
cursor.execute("SELECT * FROM users")
rows = cursor.fetchall()

# Display results using pandas DataFrame for better readability
df_users = pd.DataFrame(rows, columns=[desc[0] for desc in cursor.description])
display(df_users)

# Close the connection when done
conn.close()
print("Database connection closed.")
# Out:
#    id     name                email
# 0   1    Alice    alice@example.com
# 1   2      Bob      bob@example.com
# 2   3  Charlie  charlie@example.com
# Database connection closed.
